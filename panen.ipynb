# %% [markdown]
# <a href="https://colab.research.google.com/github/handaruabyu-eng/sistem-panen-berkelompok/blob/fitur-input/panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_data():
    nama = input("Masukkan jenis hasil panen: ")
    jumlah = float(input("Masukkan jumlah hasil panen (kg): "))
    harga = float(input("Masukkan harga per kg: "))

    return nama, jumlah, harga
